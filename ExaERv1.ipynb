# %%
from graphviz import Digraph
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/pgomezbe/OneDrive - Otto Group/Escritorio/wsdmv/.venvs/windows_10_cmake_Release_Graphviz-11.0.0-win64/Graphviz-11.0.0-win64/bin/'

# %%
# Definition of the Diagraph
dot = Digraph('AQUABUSINESSUNIT4')
dot.attr(rankdir='TB', splines='ortho')
dot.attr(labelloc='t')
dot.attr(label=r'\nData Model of AQUA Business Unit by Data Team')
dot.attr(fontsize  = '6')
dot.attr(fontcolor = 'blue')

# PK/FK's Legend (adapted to ensure that no unwanted border appears)
dot.node('Legend', '''<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="0" CELLPADDING="2">
                        <TR><TD><FONT POINT-SIZE="6" COLOR="#ED1C24">Primary Key</FONT></TD></TR>
                        <TR><TD><FONT POINT-SIZE="6" COLOR="#22B14C">Foreign Key</FONT></TD></TR>
                      </TABLE>>''', shape='plaintext')

# Metadata from Aqua App
metadataaqua = {
    'cc_aqualgsendungpos': {
        'fksize': 7,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "sendungstatus:number(22)",
            "sendungtransfer:number(22)",
            "sendungsnr:number(22)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "liefnr:number(22)",
            "anzart:number(22)",
            "qualitaetskennziffer:number(22)",
            "verpackungsziffer:number(22)",
            "anzartmuster:number(22)"
        ]
    },
    'cc_aqualgwaeing': {
        'fksize': 8,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "waeingdruck:number(22)",
            "sendungstatus:number(22)",
            "waeingerfassung:number(22)",
            "lkwnr:number(22)",
            "warenannahmeprotokollnr:number(22)",
            "tornr:number(22)",
            "herkunftnr:number(22)",
            "usernr:number(22)",
            "speditionsname:varchar2(200)",
            "wapdruckdat:date(7)",
            "wapkorrekturstatus:number(22)",
            "optischelesestationsnr:number(22)",
            "waeingnr:number(22)",
            "waeingdat:date(7)"
        ]
    },
    'cc_aqualgwaeingpos': {
        'fksize': 9,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "sendungstatus:number(22)",
            "waeingpostransfer:number(22)",
            "waeingposarchiviert:number(22)",
            "pruefmusterziehungskriterium:number(22)",
            "waeingnr:number(22)",
            "waeingposnr:number(22)",
            "sendungsnr:number(22)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "anzartkolli:number(22)",
            "anzkolli:number(22)",
            "anzartqs:number(22)",
            "karton:number(22)",
            "blattnr:number(22)",
            "freigabedat:date(7)",
            "gewichtingramm:number(22)",
            "anzartdiff:number(22)",
            "transfergeneration:number(22)",
            "pruefmusterziehungsproto:varchar2(2000)",
            "art_id:number(22)",
            "artgr_id:number(22)",
            "artgrvt_id:varchar2(88)",
            "liefartgr_id:varchar2(88)",
            "qmwaeing_id:varchar2(88)"
        ]
    },
        'cc_aquaqmklaerfall': {
        'fksize': 7,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "erweitertestichprobe:number(22)",
            "loeschung:number(22)",
            "qmklaerfall_id:varchar2(80)",
            "qmwaeing_id:varchar2(80)",
            "klaerfallnr:number(22)",
            "eingangsdat:date(7)",
            "ausgangsdat:date(7)",
            "schnitttageanz:number(22)",
            "bemerkung:varchar2(4000)",
            "logistikanfordermenge:varchar2(240)",
            "logistikanforderausgangsdat:date(7)",
            "logistikanfordereingangsdat:date(7)",
            "ekinfoausgangsdat:date(7)",
            "qeinfoausgangsdat:date(7)",
            "qeentscheideingangsdat:date(7)",
            "demoanz:number(22)",
            "stichprobeanz:number(22)",
            "fehlerteilanz:number(22)",
            "qeinfo:varchar2(4000)",
            "ekentscheideingangsdat:date(7)",
            "klaertageanz:number(22)",
            "lotageanz:number(22)",
            "einkauftageanz:number(22)",
            "qetageanz:number(22)",
            "qmreklamation_id:varchar2(88)",
            "benutzerkf_id:varchar2(80)",
            "benutzerek_id:varchar2(80)",
            "benutzerqe_id:varchar2(80)"
        ]
    },
    'cc_aquaqmmangel': {
        'fksize': 8,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "akzeptiert:number(22)",
            "info:number(22)",
            "loeschung:number(22)",
            "qmmangel_id:varchar2(80)",
            "qmklaerfall_id:varchar2(80)",
            "mangelnr:number(22)",
            "anz:number(22)",
            "textwp:varchar2(4000)",
            "textqe:varchar2(4000)",

        ]
    },
    'cc_aquaqmmasstab': {
        'fksize': 5,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "qmmasstab_id:varchar2(80)",
            "pdmmesspktartgr_id:varchar2(80)",
            "qmwaeingpos_id:varchar2(80)",
            "ist:number(22)",
            "vorderwaesche:number(22)",
            "nachderwaesche:number(22)",
            "nachdembuegeln:number(22)"
        ]
    },
    'cc_aquaqmnabfirma': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "loeschung:number(22)",
            "qmnabfirma_id:varchar2(80)",
            "name:varchar2(800)",
            "strasse:varchar2(400)",
            "plz:varchar2(20)",
            "ort:varchar2(400)",
            "telefon:varchar2(200)",
            "fax:varchar2(200)",
            "email:varchar2(400)"
        ]
    },
    'cc_aquaqmpruefer': {
        'fksize': 11,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "loeschung:number(22)",
            "klaerfall:number(22)",
            "reklamation:number(22)",
            "warenpruefer:number(22)",
            "zusqe:number(22)",
            "zuset:number(22)",
            "qmpruefer_id:varchar2(80)",
            "pruefernr:number(22)",
            "tischnr:number(22)",
            "name:varchar2(800)"
        ]
    },
    'cc_aquaqmqzahl': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "loeschung:number(22)",
            "qmqzahl_id:varchar2(80)",
            "qualitaetszifferngruppe:number(22)",
            "qualitaetsziffer:number(22)",
            "qualitaetspunkte:number(22)",
            "qualitaetszifferbez:varchar2(800)",
            "qmqzgruppe_id:varchar2(80)",
            "qualitaetsgruppe_nr:number(22)",
            "qualitaetsgruppe_bez:varchar2(1024)"
        ]
    },
    'cc_aquaqmreklamation': {
        'fksize': 7,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "komplettablehnung:number(22)",
            "loeschung:number(22)",
            "qmreklamation_id:varchar2(80)",
            "sendungsnr:number(22)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "nabadmindat:date(7)",
            "lieferanteninfodat:date(7)",
            "versanddemodat:date(7)",
            "nachbearbeitungdat:date(7)",
            "warenruecksendungdat:date(7)",
            "warenruecksendungbuchdat:date(7)",
            "anzstichsoll:number(22)",
            "anzstichist:number(22)",
            "bemerkungstich:varchar2(4000)",
            "anzstichfehl:number(22)",
            "anzdemo:number(22)",
            "anzwahl:number(22)",
            "anznachbearb:number(22)",
            "qsausgangsdat:date(7)",
            "vorschlag:varchar2(4000)",
            "grund:varchar2(4000)",
            "nachbearb:varchar2(4000)",
            "qmnabfirma_id:varchar2(80)",
            "kostenbelastung:number(22)",
            "qmbeilage_id:varchar2(80)",
            "warenruecksendungstk:number(22)",
            "nabeingangsdat:date(7)",
            "qeausgangsdat:date(7)",
            "qeeingangsdat:date(7)",
            "qmklaerfall_id:varchar2(80)"
        ]
    },
    'cc_aquaqmtextbaustein': {
        'fksize': 5,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "id:varchar2(80)",
            "kurzbez:varchar2(80)",
            "text:varchar2(4000)",
            "loesch:number(22)",
            "nr:number(22)",
            "qmtextbausteintypid:varchar2(80)"
        ]
    },
    'cc_aquaqmwaeing': {
        'fksize': 7,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "etber:number(22)",
            "eanbarcodeok:number(22)",
            "lief_id:varchar2(88)",
            "art_id:varchar2(88)",
            "qmklaerfall_id:varchar2(80)",
            "qmwaeing_id:varchar2(80)",
            "sendungsnr:number(22)",
            "liefnr:number(22)",
            "artnr:number(22)",
            "eingangsdat:date(7)",
            "qmpruefer_id:varchar2(80)",
            "qzintern_id:varchar2(80)",
            "prio:number(22)",
            "bemerkung:varchar2(4000)",
            "teleinfo:varchar2(4000)",
            "status:number(22)",
            "wbkausgangsdat:date(7)",
            "wbkeingangsdat:date(7)",
            "auslscheindat:date(7)",
            "pruefberichtdat:date(7)",
            "ausgangsdat:date(7)",
            "transfer:number(22)",
            "einlagerscheindat:date(7)",
            "qmstatus_id:varchar2(80)",
            "konzernliefsta_id:varchar2(80)"
        ]
    },
    'cc_aquaqmwaeingpos': {
        'fksize': 5,
        'columns': [
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "qmwaeingpos_id:varchar2(80)",
            "qmwaeing_id:varchar2(80)",
            "artgr:varchar2(12)",
            "anzart:number(22)",
            "anzartqs:number(22)",
            "ausgangsdat:date(7)",
            "status:number(22)",
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)"
        ]
    },
    'cc_aquaqmweprio': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "erstausstattung:number(22)",
            "qmweprio_id:varchar2(80)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "nalimenge:number(22)",
            "aquikatanz:number(22)",
            "prio:number(22)",
            "naliaquimenge:number(22)"
        ]
    }
}


for table, info in metadataaqua.items():
    label = f'''<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="0" CELLPADDING="2">
                    <TR><TD COLSPAN="2"><FONT POINT-SIZE="6"><B>{table}</B></FONT></TD></TR>
                    <TR><TD COLSPAN="2" COLOR="#ED1C24"><FONT POINT-SIZE="6" COLOR="#ED1C24">{info['columns'][0]}</FONT></TD></TR>
                    <TR><TD COLSPAN="2" BORDER="1" COLOR="#22B14C">'''
    # Determining the FK size
    fksize = info['fksize']
    # Initialize the line used by every column in the table.
    line = ""
    # Drawing FK
    line += '''<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="0">'''
    for fk in range(1, fksize+1):
        line += f'''<TR><TD COLSPAN="2" BORDER="0"><FONT POINT-SIZE="6" COLOR="#22B14C">{info['columns'][fk]}</FONT></TD></TR>'''
    line += "</TABLE></TD></TR>"
    # Drawing the rest of columns of a table
    for cols in range(fksize+1, len(info['columns'])):
        line += f'''<TR><TD COLSPAN="2" BORDER="0"><FONT POINT-SIZE="6">{info['columns'][cols]}</FONT></TD></TR>'''
    # Building the static web page in HTML to be painted by graphviz
    htmlpage = label + line + "</TABLE>>"
    #print(htmlpage)
    dot.node(table, label=htmlpage, shape='plaintext')

# Relationships among created AQUA tables 
relationship = [
  ('cc_aquaqmwaeing', 'cc_aqualgwaeingpos', 'cc_aquaqmwaeing_pk'),
  ('cc_aquaqmwaeing', 'cc_aquaqmklaerfall', 'cc_aquaqmwaeing_pk'),
  ('cc_aquaqmreklamation', 'cc_aquaqmklaerfall', 'cc_aquaqmreklamation_pk'),
  ('cc_aquaqmklaerfall', 'cc_aquaqmmangel', 'cc_aquaqmklaerfall_pk'),
  ('cc_aquaqmwaeingpos', 'cc_aquaqmmasstab', 'cc_aquaqmwaeingpos_pk'),
  ('cc_aquaqmklaerfall', 'cc_aquaqmpruefer', 'cc_aquaqmklaerfall_pk'),
  ('cc_aquaqmreklamation', 'cc_aquaqmpruefer', 'cc_aquaqmreklamation_pk'),
  ('cc_aquaqmklaerfall', 'cc_aquaqmreklamation', 'cc_aquaqmklaerfall_pk'),
  ('cc_aquaqmnabfirma', 'cc_aquaqmreklamation', 'cc_aquaqmnabfirma_pk'),
  ('cc_aquaqmklaerfall', 'cc_aquaqmwaeing', 'cc_aquaqmklaerfall_pk'),
  ('cc_aquaqmpruefer', 'cc_aquaqmwaeing', 'cc_aquaqmpruefer_pk'),
  ('cc_aquaqmwaeing', 'cc_aquaqmwaeingpos', 'cc_aquaqmwaeing_pk')
]

# Creates these relationships iteratively
for from_table, to_table, key in relationship:
    dot.edge(from_table, to_table, headlabel=key, fontsize='6')

dot.view()
# Out:
# 'AQUABUSINESSUNIT4.gv.pdf'

# %%
# Creates the PDF called as Aqua_Data_Model_v4
dot.render('Aqua_Data_Model_v4', format='pdf', view=True)
# Out:
# 'Aqua_Data_Model_v4.pdf'
