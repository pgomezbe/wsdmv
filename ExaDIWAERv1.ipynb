# %%
from graphviz import Digraph
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/pgomezbe/OneDrive - Otto Group/Escritorio/wsdmv/.venvs/windows_10_cmake_Release_Graphviz-11.0.0-win64/Graphviz-11.0.0-win64/bin/'

# %%
# Definition of the Diagraph
#dot = Digraph('DIWABUSINESSUNIT1')
dot = Digraph('Z1')
dot.attr(rankdir='TB', splines='ortho')
dot.attr(labelloc='t')
dot.attr(label=r'\nDATA MODEL OF DIWA')
dot.attr(fontsize  = '6')
dot.attr(fontcolor = 'blue')

# PK/FK's Legend (adapted to ensure that no unwanted border appears)
dot.node('Legend', '''<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="0" CELLPADDING="2">
                        <TR><TD><FONT POINT-SIZE="6" COLOR="#ED1C24">Primary Key</FONT></TD></TR>
                        <TR><TD><FONT POINT-SIZE="6" COLOR="#22B14C">Foreign Key</FONT></TD></TR>
                      </TABLE>>''', shape='plaintext')

# Metadata from Aqua App
metadatadiwa = {
    'cc_diwaart': {
        'fksize': 8,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "diwastiltyp:number(22)",
            "diwabestueckungsalter:number(22)",
            "diwaart_id:varchar2(80)",
            "artnr:number(22)",
            "alfaart_id:varchar2(80)",
            "mvnrakt:number(22)",
            "liefertermin:date(7)",
            "bem:varchar2(4000)",
            "bemauftrag:varchar2(800)",
            "wiedervorlagedat:date(7)",
            "anldat:date(7)",
            "letztaenddat:date(7)"
        ]
    },
    'cc_diwaartlief': {
        'fksize': 7,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "prioritaet:number(22)",
            "diwaartlief_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "lief_id:varchar2(80)",
            "stylenr:varchar2(120)",
            "stylefarbe:varchar2(200)",
            "stylebez:varchar2(1000)"
        ]
    },
    'cc_diwaartmarker': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwamarker:number(22)",
            "diwaartmarker_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "benutzeranl:varchar2(80)",
            "anldat:date(7)"
        ]
    },
    'cc_diwaartsaison': {
        'fksize': 9,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "umseksaison:number(22)",
            "diwasaisongrad:number(22)",
            "obermarktkz:number(22)",
            "art_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "mvnr:number(22)",
            "anldat:date(7)",
            "letztaenddat:date(7)",
            "diwaartsaison_id:varchar2(80)"
        ]
    },
    'cc_diwaartvt': {
        'fksize': 8,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "ausstattquotealternativ:number(22)",
            "firma:number(22)",
            "diwaartvt_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "bem:varchar2(1600)",
            "nabrisikowoche:number(22)"
        ]
    },
    'cc_diwaartvtgrp': {
        'fksize': 18,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwagrverteilung:number(22)",
            "anzeigeaktivmkz:number(22)",
            "anzeigeaktivmodell:number(22)",
            "anzeigeaktivartikel:number(22)",
            "anzeigeaktivmanuell:number(22)",
            "diwastatusaqoa:number(22)",
            "diwastatusaqoaonline:number(22)",
            "diwastatusaqoaoffline:number(22)",
            "diwastatusaqoagrenzwertonline:number(22)",
            "diwastatusaqoagrenzwertoffline:number(22)",
            "anzeigeaktivonline:number(22)",
            "anzeigeaktivoffline:number(22)",
            "anzeigeaktivvtgg:number(22)",
            "diwaartvtgrp_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "vtggruppe:varchar2(80)",
            "aqoa:number(22)",
            "erfolgfaktor:number(22)",
            "erfolgfaktormanuell:number(22)",
            "erfolgfaktorkatalog:number(22)",
            "erfolgfaktorvtgrp:number(22)",
            "anldat:date(7)",
            "letztaenddat:date(7)",
            "aqoamanuell:number(22)",
            "aqoaonline:number(22)",
            "aqoaoffline:number(22)",
            "aqoamanuellonline:number(22)",
            "aqoamanuelloffline:number(22)",
            "aqoadefaultonline:number(22)",
            "aqoadefaultoffline:number(22)"
        ]
    },
    'cc_diwadgpanforderung': {
        'fksize': 10,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "bestandreservierung:number(22)",
            "komplettabnahme:number(22)",
            "abgelehntbearb:number(22)",
            "diwastatusdgpanforderung:number(22)",
            "stsaisonwerte_id:varchar2(80)",
            "anforderungstk:number(22)",
            "libgeliefertstk:number(22)",
            "libteilmg:number(22)",
            "abrufdat:date(7)",
            "anldat:date(7)",
            "benutzeranl:varchar2(80)",
            "letztaenddat:date(7)",
            "benutzerletztaend:varchar2(80)",
            "bem:varchar2:2000",
            "rnwsollmg:number(22)",
            "erstabrufdat:date(7)",
            "diwadgpgr_id:varchar2(80)",
            "diwadgpanforderung_id:varchar2(80)"
        ]
    },
    'cc_diwadgpgr': {
        'fksize': 8,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "umseksaison:number(22)",
            "diwadgp:number(22)",
            "diwadgpgr_id:varchar2(80)",
            "diwagr_id:varchar2(80)",
            "hrstk:number(22)",
            "hrreststk:number(22)",
            "gewstk:number(22)",
            "ansprmenge:number(22)",
            "brabsmenge:number(22)",
            "retmenge:number(22)"
        ]
    },
    'cc_diwagr': {
        'fksize': 9,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "eksaison:number(22)",
            "erledigt:number(22)",
            "grvertaktiv:number(22)",
            "diwagr_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "mvgr:varchar2(32)",
            "alfagr_id:varchar2(80)",
            "dispomgstk:number(22)",
            "dispodat:date(7)",
            "anldat:date(7)",
            "letztaenddat:date(7)",
            "bedarf:number(22)",
            "limitabschreibung:number(22)"
        ]
    },
    'cc_diwagrvt': {
        'fksize': 9,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "artverwendungextern:number(22)",
            "saisonextern:number(22)",
            "vtg:number(22)",
            "diwagrvt_id:varchar2(80)",
            "artverwendungletztaenddat:date(7)",
            "nachschubzusstk:number(22)",
            "nachschubzusstkletztaenddat:date(7)",
            "diwagr_id:varchar2(80)",
            "lib:number(22)",
            "lab:number(22)",
            "mgspeicher:number(22)",
            "dispomg:number(22)",
            "dispomgkorr:number(22)"
        ]
    },
    'cc_diwagrvtgrp': {
        'fksize': 5,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwagrvtgrp_id:varchar2(80)",
            "diwaartvtgrp_id:varchar2(80)",
            "diwagr_id:varchar2(80)",
            "grvertproz:number(22)",
            "grvertprozmanuell:number(22)",
            "anldat:date(7)",
            "letztaenddat:date(7)"
        ]
    },
    'cc_diwakalenderplan': {
        'fksize': 5,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwakalenderplan_id:varchar2(80)",
            "diwa_kalender_id:varchar2(80)",
            "anzwochennachversand:number(22)",
            "nachfrageverteilungproz:number(22)"
        ]
    },
    'cc_diwakatvt': {
        'fksize': 9,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "katart:number(22)",
            "umseksaison:number(22)",
            "diwakatvtverarb:number(22)",
            "firma:number(22)",
            "diwakatvt_id:varchar2(80)",
            "diwa_kalender_id:varchar2(80)",
            "diwakatvtprognoseaktiv_id:varchar2(80)",
            "anstossdat:date(7)",
            "anldat:date(7)",
            "letztaenddat:date(7)",
            "ansprwert:number(22)"
        ]
    },
    'cc_diwakatvtetber': {
        'fksize': 7,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "etberbt:number(22)",
            "feinsteueren:number(22)",
            "diwakatvtetber_id:varchar2(80)",
            "diwakatvt_id:varchar2(80)",
            "diwa_kat_etber_id:varchar2(80)",
            "katalogfaktor:number(22)",
            "anldat:date(7)",
            "letztaenddat:date(7)"
        ]
    },
    'cc_diwakatvtprognose': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwaprognosetyp:number(22)",
            "diwakatvtprognose_id:varchar2(80)",
            "diwakatvt_id:varchar2(80)",
            "anldat:date(7)",
            "letztaenddat:date(7)",
            "benutzeridanl:varchar2(80)",
            "prognosewert:number(22)"     
        ]
    },
    'cc_diwanachschub': {
        'fksize': 9,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwanachschub_id:varchar2(80)",
            "diwastatussendung:number(22)",
            "diwagrvt_id:varchar2(80)",
            "liefversandart:number(22)",
            "dwh_aktiv:number(22)",
            "anldat:date(7)",
            "benutzeranl_id:varchar2(80)",
            "ponumber:varchar2(80)"
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "menge:number(22)",
            "versanddat:date(7)",
            "waeingdatext:date(7)",
            "letztaenddat:date(7)",
            "benutzerletztaend_id:varchar2(80)"
       ]
    },
    'cc_diwaomkzprognose': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "obermarktkz:number(22)",
            "diwaomkzprognose_id:varchar2(80)",
            "diwakatvtprognose_id:varchar2(80)",
            "diwasaisongrad:varchar2(80)",
            "verteilungsschluesselproz:number(22)",
            "prognosewert:number(22)",
            "hrfaktor:number(22)",
            "ansprwert:number(22)",
            "anspr:number(22)",
            "letztaenddat:date(7)"
       ]
    },
    'cc_diwaprom': {
        'fksize': 12,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "katart:number(22)",
            "umseksaison:number(22)",
            "diwazukauf:number(22)",
            "einsatzusa:number(22)",
            "einsatzhenson:number(22)",
            "prom_id:number(22)",
            "diwaprom_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "promnr:varchar2(12)",
            "diwa_kat_etber_id:varchar2(80)",
            "alfaprom_id:varchar2(80)",
            "anldat:date(7)",
            "letztaenddat:date(7)"
       ]
    },
    'cc_diwapromgrvt': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "diwapromgrvt_id:varchar2(80)",
            "diwapromvt_id:varchar2(80)",
            "anspr:number(22)",
            "ansprwert:number(22)",
            "gewstk:number(22)",
            "gewstk_diamant:number(22)",
            "gewwert:number(22)",
            "nab:number(22)",
            "naboffen:number(22)",
            "nabstorno:number(22)",
            "brabs:number(22)",
            "nili:number(22)",
            "nali:number(22)",
            "nina:number(22)",
            "ret:number(22)",
            "prognose:number(22)",
            "prognosewert:number(22)",
            "hrreststk:number(22)",
            "hrstk:number(22)",
            "hrstk_ef:number(22)",
            "anldat:date(7)",
            "letztaenddat:date(7)",
            "diwagr_id:varchar2(80)",
            "nabaeltoffen_tt:number(22)",
            "promgrvt_id:varchar2(80)"
       ]
    },
    'cc_diwapromvt': {
        'fksize': 12,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "titel:number(22)",
            "subvk:number(22)",
            "ruecktitel:number(22)",
            "firma:number(22)",
            "erfolgsfaktorverw:number(22)",
            "diwahrtyp:number(22)",
            "diwapromvt_id:varchar2(80)",
            "diwaart_id:varchar2(80)",
            "diwaartvtgrp_id:varchar2(80)",
            "diwakatvt_id:varchar2(80)",
            "diwakatvtetber_id:varchar2(80)",
            "diwaprom_id:varchar2(80)",
            "gewmanuell:number(22)",
            "anldat:date(7)",
            "letztaenddat:date(7)",
            "onlineaufschlagproz:number(22)",
            "mvnr:number(22)"
       ]
    },
    'cc_diwapromvthist': {
        'fksize': 5,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwapromvthist_id:varchar2(80)",
            "diwapromvt_id:varchar2(80)",
            "diwa_kat_historie_id:varchar2(80)",
            "hrstk:number(22)",
            "diwaprognosetyp_id:number(22)"
       ]
    },
    'cc_diwauebbedusa': {
        'fksize': 7,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "diwagr_id:varchar2(20)",
            "diwaart_id:varchar2(20)",
            "dwh_aktiv:number(22)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "uebbedusa:number(22)",
            "numsmengeusa_promsgewichtet:number(22)",
            "obligousa:number(22)"
       ]
    }
}


for table, info in metadatadiwa.items():
    label = f'''<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="0" CELLPADDING="2">
                    <TR><TD COLSPAN="2"><FONT POINT-SIZE="6"><B>{table}</B></FONT></TD></TR>
                    <TR><TD COLSPAN="2" COLOR="#ED1C24"><FONT POINT-SIZE="6" COLOR="#ED1C24">{info['columns'][0]}</FONT></TD></TR>
                    <TR><TD COLSPAN="2" BORDER="1" COLOR="#22B14C">'''
    # Determining the FK size
    fksize = info['fksize']
    # Initialize the line used by every column in the table.
    line = ""
    # Drawing FK
    line += '''<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="0">'''
    for fk in range(1, fksize+1):
        line += f'''<TR><TD COLSPAN="2" BORDER="0"><FONT POINT-SIZE="6" COLOR="#22B14C">{info['columns'][fk]}</FONT></TD></TR>'''
    line += "</TABLE></TD></TR>"
    # Drawing the rest of columns of a table
    for cols in range(fksize+1, len(info['columns'])):
        line += f'''<TR><TD COLSPAN="2" BORDER="0"><FONT POINT-SIZE="6">{info['columns'][cols]}</FONT></TD></TR>'''
    # Building the static web page in HTML to be painted by graphviz
    htmlpage = label + line + "</TABLE>>"
    #print(htmlpage)
    dot.node(table, label=htmlpage, shape='plaintext')



dot.view()
# Out:
# 'Z1.gv.pdf'

# %%
# Creates the PDF called as DIWA_Data_Model_v1
#dot.render('DIWA_Data_Model_v1', format='pdf', view=True)
