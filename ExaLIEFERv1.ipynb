# %%
from graphviz import Digraph
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/pgomezbe/OneDrive - Otto Group/Escritorio/wsdmv/.venvs/windows_10_cmake_Release_Graphviz-11.0.0-win64/Graphviz-11.0.0-win64/bin/'

# %%
# Definition of the Diagraph
dot = Digraph('Z1')
#dot = Digraph('LIEFBUSINESSUNIT1')
dot.attr(rankdir='TB', splines='ortho')
dot.attr(labelloc='t')
dot.attr(label=r'\nDATA MODEL OF LIEF')
dot.attr(fontsize  = '6')
dot.attr(fontcolor = 'blue')

# PK/FK's Legend (adapted to ensure that no unwanted border appears)
dot.node('Legend', '''<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="0" CELLPADDING="2">
                        <TR><TD><FONT POINT-SIZE="6" COLOR="#ED1C24">Primary Key</FONT></TD></TR>
                        <TR><TD><FONT POINT-SIZE="6" COLOR="#22B14C">Foreign Key</FONT></TD></TR>
                      </TABLE>>''', shape='plaintext')

# Metadata from Aqua App
metadatadiwa = {
    'cc_lief': {
        'fksize': 14,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "lief_id:varchar2(88)",
            "mercedeslief:number(22)",
            "aussengeprueft:number(22)",
            "problemlief:number(22)",
            "land:number(22)",
            "auslandsbuero:number(22)",
            "liefaktiv:number(22)",
            "liefekaktiv:number(22)",
            "lieftyp:number(22)",
            "konzernliefsta_id:varchar2(80)",
            "liefnrzentral:number(22)",
            "name:varchar2(200)",
            "strasse:varchar2(480)",
            "plz:varchar2(40)",
            "ort:varchar2(240)",
            "adresszusatz:varchar2(480)",
            "limitmercedes:number(22)",
            "liefnr:number(22)",
            "email:varchar2(800)",
            "telefon:varchar2(160)",
            "fax:varchar2(160)",
            "anldat:date(7)",
            "liefbonus:number(22)",
            "eanpflicht:number(22)",
            "eusteuernr:varchar2(60)",
            "b2bversandabw:number(22)",
            "rechkontrollbem:varchar2(4000)",
            "liefversandbestimmung:number(22)",
            "liefortbestimmung:number(22)"
       ]
    },
    'cc_liefartgr': {
        'fksize': 11,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefartgr_id:varchar2(120)",
            "artgr:varchar2(12)",
            "artgr_id:number(22)",
            "artgrvt_id:number(22)",
            "artnr:number(22)",
            "liefnr:number(22)",
            "bek:number(22)",
            "bekfremd:number(22)",
            "art_id:number(22)",
            "lief_id:varchar2(88)",
            "eksaison:number(22)",
            "liefverpackung:number(22)",
            "liefartverpackung:number(22)",
            "mwst:number(22)",
            "liefart:number(22)",
            "minbestmenge:number(22)",
            "liefversandart:number(22)",
            "liefstylenr:varchar2(120)",
            "liefstylefarbe:varchar2(200)",
            "liefstylebez:varchar2(1000)",
            "wiederbeschaffungszeit:number(22)",
            "konzernliefsta_id:varchar2(80)",
            "erridat:date(7)",
            "aenddat:date(7)"
       ]
    },
    'cc_liefartgrean': {
        'fksize': 10,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "liefartgrean_id:varchar2(200)",
            "liefartgr_id:varchar2(12)",
            "stverw:number(22)",
            "wittetikettdruck:number(22)",
            "aenddat:date(7)",
            "eksaison:number(22)",
            "liefnr:number(22)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "eancode:varchar2(52)"
       ]
    },
    'cc_liefauftrartgr': {
        'fksize': 16,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "liefauftrartgr_id:number(22)",
            "liefauftrartnr_id:number(22)",
            "liefauftrkopf_id:number(22)",
            "auftrnr:number(22)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "auftrdat:date(7)",
            "liefnr:number(22)",
            "artnr:number(22)",
            "artgr:number(22)",
            "bek:number(22)",
            "bekfremd:number(22)",
            "auftrmg:number(22)",
            "erlaendsto:number(22)",
            "erlaendstodat:date(7)",
            "refauftrnr:number(22)",
            "splitting:number(22)",
            "liefmgrabattstaf:number(22)",
            "bekdia:number(22)",
            "bekfremddia:number(22)"
       ]
    },
        'cc_liefauftrartgrstorno': {
        'fksize': 16,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefauftrartgrstorno_id:varchar2(40)",
            "auftrnr:number(22)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "stornodat:date(7)",
            "artnr:number(22)",
            "artgr:number(22)",
            "erlaendsto:number(22)",
            "arttot:varchar2(2)",
            "halbgr:number(22)",
            "liefmgrabattstafpos:varchar2(80)",
            "liefnr:number(22)",
            "bek:number(22)",
            "bekfremd:number(22)",
            "bekfremddia:number(22)",
            "auftrmenge:number(22)",
            "diffauftrmenge:number(22)",
            "auftrmengealt:number(22)",
            "usernr:number(22)",
            "referenzauftrnr:number(22)",
            "benutzer:varchar2(80)",
            "bekdia:number(22)"
       ]
    },
    'cc_liefauftrartnr': {
        'fksize': 14,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "liefauftrartnr_id:number(22)",
            "liefauftrkopf_id:number(22)",
            "auftrnr:number(22)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "auftrdat:date(7)",
            "liefnr:number(22)",
            "artnr:number(22)",
            "liefartverp:number(22)",
            "haengendliegend:number(22)",
            "eintfrei:number(22)",
            "wagrp:number(22)",
            "refanfrnr:number(22)",
            "refanfrdat:date(7)",
            "dispobemerkung:varchar2(2800)"
       ]
    },
    'cc_liefauftrartnrstorno': {
        'fksize': 16,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefauftrartnrstorno_id:varchar2(30)",
            "auftrnr:number(22)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "stornodat:date(7)",
            "artnr:number(22)",
            "haengendliegend:number(22)",
            "einteilungsfrei:number(22)",
            "erlaendsto:number(22)",
            "b2bbearbeitungsstatus:number(22)",
            "liefbekaenderungsgrund:varchar2(10)",
            "liefnr:number(22)",
            "liefartverpackung:number(22)",
            "wittartbeschrtext:varchar2(2000)",
            "liefartbeschrtext:varchar2(200)",
            "usernr:number(22)",
            "wagrpkt:varchar2(4)",
            "wittartbeschrtextfremd:varchar2(2000)",
            "erstaustattungdispo:varchar2(4)",
            "benutzer:varchar2(80)",
            "suppliermemo:varchar2(4000)",
            "officememo:varchar2(4000)",
            "orderstatuscode:number(22)",
            "orderstatusdat:date(7)",
            "sonstaenderungsgrundtext:varchar2(400)",
            "referenzanfragenr:number(22)",
            "referenzanfragedat:date(7)"
       ]
    },
    'cc_liefauftrartnrtext': {
        'fksize': 12,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date:(7)",
            "liefauftrartnrtext_id:varchar2(80)",
            "auftrnr:number(22)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "artnr:number(22)",
            "auftragtextart:number(22)",
            "auftragtext:number(22)",
            "liefnr:number(22)",
            "textbez:varchar2(1000)"
       ]
    },
    'cc_liefauftrkopf': {
        'fksize': 12,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "liefauftrkopf_id:number(22)",
            "auftrnr:number(22)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "auftrdat:date(7)",
            "liefnr:number(22)",
            "liefbelegart:number(22)",
            "litermingewue:date(7)",
            "literminbestae:date(7)",
            "literminberrechdat:date(7)",
            "etberkt:number(22)",
            "etberst:number(22)",
            "etberbt:number(22)",
            "liefverpackung:number(22)",
            "liefversandbestimmung:number(22)",
            "liefskonto:number(22)",
            "liefortbestimmung:number(22)",
            "waehrung:number(22)",
            "valuta_tt:number(22)",
            "lieforderart:number(22)",
            "blocknr:number(22)",
            "liefdruck:number(22)",
            "liefversandart:number(22)",
            "b2bbearbstat:number(22)",
            "refsplitnrovh:varchar2(56)",
            "auslbueronr:number(22)",
            "orderstatusdate:date(7)",
            "aenddat:date(7)",
            "liefprio:number(22)",
            "sovaref:varchar2(80)",
            "usauebertragung:number(22)"
       ]
    },
    'cc_liefauftrkopfstorno': {
        'fksize': 30,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefauftrkopfstorno_id:varchar2(24)",
            "auftrnr:number(22)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "liefbelegart:number(22)",
            "etberkt:number(22)",
            "etberst:number(22)",
            "etberbt:number(22)",
            "auftrvisiert:number(22)",
            "lieferanschrift:number(22)",
            "verpackung:number(22)",
            "liefversandbestimmung:number(22)",
            "liefskonto:number(22)",
            "liefortbestimmung:number(22)",
            "waehrung:number(22)",
            "lieforderart:number(22)",
            "liefdruck:number(22)",
            "systemherkunft:number(22)",
            "erlaendsto:number(22)",
            "liefversandart:number(22)",
            "stornoberichtigung:number(22)",
            "auslandsbuero:number(22)",
            "transfer:number(22)",
            "gtnexustransfer:number(22)",
            "liefprio:number(22)",
            "belegbemerkung:varchar2(2000)",
            "usernr:number(22)",
            "emaildisponent:varchar2(400)",
            "orderstatuscode:number(22)",
            "bearbeitungsstatus:number(22)",
            "refsplitnrovh:varchar2(80)",
            "benutzer:varchar2(80)",
            "orderstatusdat:date(7)",
            "orderstatususer:varchar2(120)",
            "auslandsbueromitarbeiter:varchar2(80)",
            "aenderungsdat:date(7)",
            "gtnexusdeclinereason:number(22)",
            "archiv:varchar2(20)",
            "stornodat:date(7)",
            "liefnr:number(22)",
            "liefertermingewuenscht:date(7)",
            "lieferterminbestaetigt:date(7)",
            "lieferterminberechdat:date(7)",
            "wagrpkt:varchar2(4)",
            "valutatag:number(22)",
            "blocknr:number(22)"
       ]
    },
    'cc_liefauftrsplitting': {
        'fksize': 15,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "dwh_aktiv:number(22)",
            "liefauftrsplitting_id:number(22)",
            "artnr:number(22)",
            "artgr:number(22)",
            "auftrnr:number(22)",
            "liefnr:number(22)",
            "lfdnr:number(22)",
            "eksaison:number(22)",
            "penalty:number(22)",
            "liefnichtpenaltygrund:number(22)",
            "auftrdat:date(7)",
            "litermingewue:date(7)",
            "literminberrechdat:date(7)",
            "splittmg:number(22)",
            "refauftrnr:number(22)",
            "erlaendsto:number(22)",
            "erlaendstodat:date(7)",
            "liefversart:number(22)",
            "literminbestae:date(7)",
            "sonstpenaltygrundtext:varchar2(400)"
       ]
    },
    'cc_liefauskunftbestand': {
        'fksize': 5,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "id:varchar2(256)",
            "liefauskunfttextnr:number(22)",
            "ioecommunicationkey:number(22)",
            "letztmeldedat:date(7)",
            "csiartikel:number(22)",
            "alfa_grid:varchar2(80)",
            "letztaenddat:date(7)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "mgzugesagt:number(22)",
            "mgoffen:number(22)",
            "mgersatz:number(22)",
            "bdcrsimport:number(22)",
            "letztbdcrsimportaenddat:date(7)"
       ]
    },
    'cc_liefbelegartgrtemp': {
        'fksize': 10,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefbelegartgrtemp_id:varchar2(76)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "erlaendsto:number(22)",
            "b2bbearbeitungsstatus:number(22)",
            "belegnr:number(22)",
            "liefnr:number(22)",
            "belegdat:date(7)",
            "artnr:number(22)",
            "artgr:varchar2(12)",
            "bek:number(22)",
            "bekfremd:number(22)",
            "bestellmenge:number(22)",
            "usernr:number(22)",
            "referenzauftrnr:number(22)",
            "auftrmengealt:number(22)",
            "freitextbemerkung:varchar2(60)",
            "orderstatuscode:number(22)",
            "benutzer:varchar2(80)",
            "liefmgrabattstafpos_id:varchar2(80)",
            "bekdia:number(22)",
            "bekfremddia:number(22)"
       ]
    },
        'cc_liefbelegartnrtemp': {
        'fksize': 15,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefbelegartnrtemp_id:varchar2(64)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "liefartverpackung:number(22)",
            "haengendliegend:number(22)",
            "einteilungsfrei:number(22)",
            "erlaendsto:number(22)",
            "wagrp:varchar2(4)",
            "b2bbearbeitungsstatus:number(22)",
            "liefbekaenderungsgrund:number(22)",
            "liefnr:number(22)",
            "belegdat:date(7)",
            "artnr:number(22)",
            "wittartbeschrtext:varchar2(2000)",
            "liefartbeschrtext:varchar2(200)",
            "usernr:number(22)",
            "artikelbemerkung:varchar2(1000)",
            "freitextbemerkung:varchar2(60)",
            "wittartbeschrtextfremd:varchar2(2000)",
            "erstaustattungdispo:varchar2(4)",
            "orderstatuscode:number(22)",
            "b2bliefertermingewuenscht:date(7)",
            "suppliermemo:varchar2(4000)",
            "officememo:varchar2(4000)",
            "referenzanfragenr:number(22)",
            "benutzer:varchar2(80)",
            "orderstatusdat:date(7)",
            "b2bversionnr:number(22)",
            "sonstaenderungsgrundtext:varchar2(400)",
            "referenzanfragedat:date(7)",
            "belegnr:number(22)"
       ]
    },
    'cc_liefbelegartnrtexttemp': {
        'fksize': 11,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefbelegartnrtexttemp_id:varchar2(80)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "textkz:number(22)",
            "textnr:number(22)",
            "erlaendsto:number(22)",
            "belegnr:number(22)",
            "liefnr:number(22)",
            "artnr:number(22)",
            "textbez:varchar2(1000)"
       ]
    },
    'cc_liefbelegkopftemp': {
        'fksize': 32,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefbelegkopftemp_id:varchar2(40)",
            "eksaison:number(22)",
            "bestandsfirma:number(22)",
            "liefbelegart:number(22)",
            "etberkt:number(22)",
            "etberst:number(22)",
            "etberbt:number(22)",
            "wagrpkt:number(22)",
            "wagrpst:number(22)",
            "wagrpbt:number(22)",
            "auftravisiert:number(22)",
            "liefanschrift:number(22)",
            "liefversandart:number(22)",
            "liefversandbestimmung:number(22)",
            "verpackung:number(22)",
            "liefskonto:number(22)",
            "liefortbestimmung:number(22)",
            "waehrung:number(22)",
            "lieforderart:number(22)",
            "liefmitarbeiter:number(22)",
            "stornoberichtigung:number(22)",
            "erlaendsto:number(22)",
            "auslandsbuero:number(22)",
            "orderstatusmemocreator:number(22)",
            "gtnexustransfer:number(22)",
            "liefprio:number(22)",
            "archiv:varchar2:(64)",
            "liefnr:number(22)",
            "belegdat:date(7)",
            "liefterminberechdat:date(7)",
            "valutatag:number(22)",
            "blocknr:number(22)",
            "wiedervorlagedatum:date(7)",
            "lieftermingewuenscht:date(7)",
            "belegbemerkung:varchar2(2000)",
            "usernr:number(22)",
            "liefterminbestaetigt:date(7)",
            "orderstatuscode:number(22)",
            "orderstatusdat:date(7)",
            "bearbeitungsstatus:number(22)",
            "orderstatususer:varchar2(120)",
            "emaildisponent:varchar2(400)",
            "b2bbelegbemerkung:varchar2(2000)",
            "refsplitnrovh:varchar2(56)",
            "benutzer:varchar2(80)",
            "auslandsbueromitarbeiter:varchar2(80)",
            "versionssnummer:number(22)",
            "gtnexusdeclinereason:varchar2(80)",
            "gtnexusupdatereason:varchar2(80)",
            "sovareferenz:varchar2(80)",
            "belegnr:number(22)"
       ]
    },
    'cc_liefmgrabattstafpos': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefmgrabattstafpos_id:varchar2(80)",
            "liefmgrabattstaffelid:varchar2(80)",
            "auftrmgvon:number(22)",
            "auftrmgbis:number(22)",
            "rabatt:number(22)"
       ]
    },
    'cc_liefobligo': {
        'fksize': 9,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefobligo_id:varchar2(60)",
            "artnr:number(22)",
            "artgr:number(22)",
            "liefnr:number(22)",
            "obligo:number(22)",
            "sysdat:date(7)",
            "systime:varchar2(100)",
            "obligoexblock:number(22)"
       ]
    },
    'cc_lieftransportdauer': {
        'fksize': 8,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "lieftransportdauer_id:varchar2(320)",
            "eksaison:number(22)",
            "land:number(22)",
            "liefversandart:number(22)",
            "transporttage:number(22)"
       ]
    },
    'cc_liefversanddauer': {
        'fksize': 8,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefversanddauer_id:varchar2(320)",
            "eksaison:number(22)",
            "liefversandart:number(22)",
            "versandtage:number(22)",
            "liefsta_id:varchar2(88)",
            "lief_id:varchar2(88)",
            "liefnr:number(22)"
       ]
    },
    'cc_liefwaeinglv': {
        'fksize': 6,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "id:varchar2(80)",
            "waeingnr:number(22)",
            "waeingdat:date(7)",
            "liefnr:number(22)",
            "artnr:number(22)",
            "artgr:number(22)",
            "etber:number(22)",
            "wagrp:number(22)",
            "bek:number(22)",
            "waeingmg:number(22)",
            "freidat:date(7)",
            "lischeinnr:varchar2(40)",
            "arbnr:number(22)",
            "erlaendsto:number(22)",
            "erlaendstodat:date(7)",
            "refauftrnr:number(22)",
            "lfdnr:number(22)",
            "sendgdat:date(7)",
            "eksaison:number(22)",
            "letztaenddat:date(7)",
            "liefsaison:number(22)",
            "artgrp:number(22)",
            "artverwendung:number(22)",
            "land:number(22)",
            "vek:number(22)",
            "bestandsfirma:number(22)",
            "eg:number(22)",
            "haengendliegend:number(22)",
            "extlagerid:varchar2(80)"
       ]
    },
    'cc_liefwunschservice': {
        'fksize': 11,
        'columns': [
            "dwh_id:number(22)",
            "dwh_cr_load_id:number(22)",
            "dwh_up_load_id:number(22)",
            "dwh_status:number(22)",
            "dwh_valid_from:date(7)",
            "dwh_valid_to:date(7)",
            "liefwunschservice_id:varchar2(80)",
            "firma:number(22)",
            "auftrart:number(22)",
            "liefwunschservicedefault:number(22)",
            "zwangskomplettierung:number(22)",
            "liefwunschkosten:number(22)",
            "udb_gueltigvon:date(7)",
            "udb_gueltigbis:date(7)",
            "sortierung:number(22)",
            "liefwunsch_id:varchar2(80)"
       ]
    }
}


for table, info in metadatadiwa.items():
    label = f'''<<TABLE BORDER="1" CELLBORDER="1" CELLSPACING="0" CELLPADDING="2">
                    <TR><TD COLSPAN="2"><FONT POINT-SIZE="6"><B>{table}</B></FONT></TD></TR>
                    <TR><TD COLSPAN="2" COLOR="#ED1C24"><FONT POINT-SIZE="6" COLOR="#ED1C24">{info['columns'][0]}</FONT></TD></TR>
                    <TR><TD COLSPAN="2" BORDER="1" COLOR="#22B14C">'''
    # Determining the FK size
    fksize = info['fksize']
    # Initialize the line used by every column in the table.
    line = ""
    # Drawing FK
    line += '''<TABLE BORDER="0" CELLBORDER="0" CELLSPACING="0">'''
    for fk in range(1, fksize+1):
        line += f'''<TR><TD COLSPAN="2" BORDER="0"><FONT POINT-SIZE="6" COLOR="#22B14C">{info['columns'][fk]}</FONT></TD></TR>'''
    line += "</TABLE></TD></TR>"
    # Drawing the rest of columns of a table
    for cols in range(fksize+1, len(info['columns'])):
        line += f'''<TR><TD COLSPAN="2" BORDER="0"><FONT POINT-SIZE="6">{info['columns'][cols]}</FONT></TD></TR>'''
    # Building the static web page in HTML to be painted by graphviz
    htmlpage = label + line + "</TABLE>>"
    #print(htmlpage)
    dot.node(table, label=htmlpage, shape='plaintext')



dot.view()
# Out:
# 'Z1.gv.pdf'

# %%
# Creates the PDF called as LIEF_Data_Model_v1
#dot.render('LIEF_Data_Model_v1', format='pdf', view=True)
